# %%
from gluonts.dataset.repository.datasets import get_dataset
from autogluon.forecasting import Forecasting as task

# %%
dataset = get_dataset("electricity_nips", regenerate=True)
train_data = dataset.train
test_data = dataset.test
# Out:
# /home/ubuntu/anaconda3/envs/ag_forecast/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# saving time-series into /home/ubuntu/.mxnet/gluon-ts/datasets/electricity_nips/train/data.json
# saving time-series into /home/ubuntu/.mxnet/gluon-ts/datasets/electricity_nips/test/data.json

# %%
prediction_length = dataset.metadata.prediction_length
freq = dataset.metadata.freq

# %%
predictor = task.fit(train_data=train_data,
                     prediction_length=prediction_length,
                     freq=freq,
                     )
# Out:
# Training with dataset in gluon-ts format...
# Validation data is not specified, will do auto splitting...
# Random seed set to 0
# All models will be trained for quantiles ['0.5'].
# Beginning AutoGluon training ...
# AutoGluon will save models to AutogluonModels/ag-20210310_115432/
# Fitting model: MQCNN ...
# Start model training
# Epoch[0] Learning rate is 0.001
#   0%|          | 0/32 [00:00<?, ?it/s]Note: NumExpr detected 16 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# NumExpr defaulting to 8 threads.
# Number of parameters in ForkingSeq2SeqTrainingNetwork: 99362
# learning rate from ``lr_scheduler`` has been overwritten by ``learning_rate`` in optimizer.
# 100%|██████████| 32/32 [00:01<00:00, 26.46it/s, epoch=1/50, avg_epoch_loss=602]
# Epoch[0] Elapsed time 1.211 seconds
# Epoch[0] Evaluation metric 'epoch_loss'=602.156921
# Epoch[1] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 27.04it/s, epoch=2/50, avg_epoch_loss=329]
# Epoch[1] Elapsed time 1.185 seconds
# Epoch[1] Evaluation metric 'epoch_loss'=328.838428
# Epoch[2] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 30.03it/s, epoch=3/50, avg_epoch_loss=205]
# Epoch[2] Elapsed time 1.067 seconds
# Epoch[2] Evaluation metric 'epoch_loss'=204.569582
# Epoch[3] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 30.40it/s, epoch=4/50, avg_epoch_loss=136]
# Epoch[3] Elapsed time 1.054 seconds
# Epoch[3] Evaluation metric 'epoch_loss'=135.723442
# Epoch[4] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 32.58it/s, epoch=5/50, avg_epoch_loss=151]
# Epoch[4] Elapsed time 0.984 seconds
# Epoch[4] Evaluation metric 'epoch_loss'=150.970323
# Epoch[5] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 35.30it/s, epoch=6/50, avg_epoch_loss=139]
# Epoch[5] Elapsed time 0.908 seconds
# Epoch[5] Evaluation metric 'epoch_loss'=138.905444
# Epoch[6] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 32.46it/s, epoch=7/50, avg_epoch_loss=137]
# Epoch[6] Elapsed time 0.987 seconds
# Epoch[6] Evaluation metric 'epoch_loss'=136.595015
# Epoch[7] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 34.32it/s, epoch=8/50, avg_epoch_loss=133]
# Epoch[7] Elapsed time 0.934 seconds
# Epoch[7] Evaluation metric 'epoch_loss'=133.211490
# Epoch[8] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 32.19it/s, epoch=9/50, avg_epoch_loss=107]
# Epoch[8] Elapsed time 0.996 seconds
# Epoch[8] Evaluation metric 'epoch_loss'=106.524910
# Epoch[9] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 31.70it/s, epoch=10/50, avg_epoch_loss=127]
# Epoch[9] Elapsed time 1.011 seconds
# Epoch[9] Evaluation metric 'epoch_loss'=126.849749
# Epoch[10] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 31.10it/s, epoch=11/50, avg_epoch_loss=118]
# Epoch[10] Elapsed time 1.030 seconds
# Epoch[10] Evaluation metric 'epoch_loss'=118.008316
# Epoch[11] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 31.28it/s, epoch=12/50, avg_epoch_loss=119]
# Epoch[11] Elapsed time 1.024 seconds
# Epoch[11] Evaluation metric 'epoch_loss'=119.230591
# Epoch[12] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 32.13it/s, epoch=13/50, avg_epoch_loss=95.3]
# Epoch[12] Elapsed time 0.997 seconds
# Epoch[12] Evaluation metric 'epoch_loss'=95.316610
# Epoch[13] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 31.08it/s, epoch=14/50, avg_epoch_loss=115]
# Epoch[13] Elapsed time 1.031 seconds
# Epoch[13] Evaluation metric 'epoch_loss'=115.228210
# Epoch[14] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 31.64it/s, epoch=15/50, avg_epoch_loss=110]
# Epoch[14] Elapsed time 1.013 seconds
# Epoch[14] Evaluation metric 'epoch_loss'=109.780168
# Epoch[15] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 34.64it/s, epoch=16/50, avg_epoch_loss=108]
# Epoch[15] Elapsed time 0.925 seconds
# Epoch[15] Evaluation metric 'epoch_loss'=107.876032
# Epoch[16] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 30.73it/s, epoch=17/50, avg_epoch_loss=87.3]
# Epoch[16] Elapsed time 1.043 seconds
# Epoch[16] Evaluation metric 'epoch_loss'=87.270369
# Epoch[17] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 31.52it/s, epoch=18/50, avg_epoch_loss=105]
# Epoch[17] Elapsed time 1.017 seconds
# Epoch[17] Evaluation metric 'epoch_loss'=104.711100
# Epoch[18] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 30.91it/s, epoch=19/50, avg_epoch_loss=99]
# Epoch[18] Elapsed time 1.037 seconds
# Epoch[18] Evaluation metric 'epoch_loss'=98.973047
# Epoch[19] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 30.65it/s, epoch=20/50, avg_epoch_loss=99.7]
# Epoch[19] Elapsed time 1.045 seconds
# Epoch[19] Evaluation metric 'epoch_loss'=99.699944
# Epoch[20] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 30.57it/s, epoch=21/50, avg_epoch_loss=97.8]
# Epoch[20] Elapsed time 1.048 seconds
# Epoch[20] Evaluation metric 'epoch_loss'=97.798675
# Epoch[21] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 34.46it/s, epoch=22/50, avg_epoch_loss=81.8]
# Epoch[21] Elapsed time 0.930 seconds
# Epoch[21] Evaluation metric 'epoch_loss'=81.797815
# Epoch[22] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 31.60it/s, epoch=23/50, avg_epoch_loss=94.5]
# Epoch[22] Elapsed time 1.014 seconds
# Epoch[22] Evaluation metric 'epoch_loss'=94.454763
# Epoch[23] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 28.62it/s, epoch=24/50, avg_epoch_loss=92.9]
# Epoch[23] Elapsed time 1.120 seconds
# Epoch[23] Evaluation metric 'epoch_loss'=92.931045
# Epoch[24] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 30.60it/s, epoch=25/50, avg_epoch_loss=92.6]
# Epoch[24] Elapsed time 1.047 seconds
# Epoch[24] Evaluation metric 'epoch_loss'=92.608151
# Epoch[25] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 31.06it/s, epoch=26/50, avg_epoch_loss=77.4]
# Epoch[25] Elapsed time 1.032 seconds
# Epoch[25] Evaluation metric 'epoch_loss'=77.420646
# Epoch[26] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 30.83it/s, epoch=27/50, avg_epoch_loss=92.6]
# Epoch[26] Elapsed time 1.039 seconds
# Epoch[26] Evaluation metric 'epoch_loss'=92.595217
# Epoch[27] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 30.84it/s, epoch=28/50, avg_epoch_loss=89.5]
# Epoch[27] Elapsed time 1.039 seconds
# Epoch[27] Evaluation metric 'epoch_loss'=89.481597
# Epoch[28] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 32.04it/s, epoch=29/50, avg_epoch_loss=91.1]
# Epoch[28] Elapsed time 1.000 seconds
# Epoch[28] Evaluation metric 'epoch_loss'=91.139429
# Epoch[29] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 31.39it/s, epoch=30/50, avg_epoch_loss=75.7]
# Epoch[29] Elapsed time 1.021 seconds
# Epoch[29] Evaluation metric 'epoch_loss'=75.657566
# Epoch[30] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 31.37it/s, epoch=31/50, avg_epoch_loss=90.2]
# Epoch[30] Elapsed time 1.021 seconds
# Epoch[30] Evaluation metric 'epoch_loss'=90.180117
# Epoch[31] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 30.81it/s, epoch=32/50, avg_epoch_loss=87.3]
# Epoch[31] Elapsed time 1.040 seconds
# Epoch[31] Evaluation metric 'epoch_loss'=87.302920
# Epoch[32] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 33.67it/s, epoch=33/50, avg_epoch_loss=87.6]
# Epoch[32] Elapsed time 0.952 seconds
# Epoch[32] Evaluation metric 'epoch_loss'=87.637832
# Epoch[33] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 31.71it/s, epoch=34/50, avg_epoch_loss=73.5]
# Epoch[33] Elapsed time 1.010 seconds
# Epoch[33] Evaluation metric 'epoch_loss'=73.546066
# Epoch[34] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 31.76it/s, epoch=35/50, avg_epoch_loss=87.6]
# Epoch[34] Elapsed time 1.009 seconds
# Epoch[34] Evaluation metric 'epoch_loss'=87.633775
# Epoch[35] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 31.18it/s, epoch=36/50, avg_epoch_loss=85.5]
# Epoch[35] Elapsed time 1.028 seconds
# Epoch[35] Evaluation metric 'epoch_loss'=85.508232
# Epoch[36] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 31.50it/s, epoch=37/50, avg_epoch_loss=85.4]
# Epoch[36] Elapsed time 1.017 seconds
# Epoch[36] Evaluation metric 'epoch_loss'=85.399399
# Epoch[37] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 31.58it/s, epoch=38/50, avg_epoch_loss=86.2]
# Epoch[37] Elapsed time 1.015 seconds
# Epoch[37] Evaluation metric 'epoch_loss'=86.166178
# Epoch[38] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 32.37it/s, epoch=39/50, avg_epoch_loss=72.3]
# Epoch[38] Elapsed time 0.990 seconds
# Epoch[38] Evaluation metric 'epoch_loss'=72.307035
# Epoch[39] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 29.86it/s, epoch=40/50, avg_epoch_loss=86.1]
# Epoch[39] Elapsed time 1.073 seconds
# Epoch[39] Evaluation metric 'epoch_loss'=86.129298
# Epoch[40] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 30.82it/s, epoch=41/50, avg_epoch_loss=83.4]
# Epoch[40] Elapsed time 1.039 seconds
# Epoch[40] Evaluation metric 'epoch_loss'=83.419071
# Epoch[41] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 34.51it/s, epoch=42/50, avg_epoch_loss=84.6]
# Epoch[41] Elapsed time 0.929 seconds
# Epoch[41] Evaluation metric 'epoch_loss'=84.626507
# Epoch[42] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 29.89it/s, epoch=43/50, avg_epoch_loss=72]
# Epoch[42] Elapsed time 1.072 seconds
# Epoch[42] Evaluation metric 'epoch_loss'=71.953903
# Epoch[43] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 29.81it/s, epoch=44/50, avg_epoch_loss=86.1]
# Epoch[43] Elapsed time 1.075 seconds
# Epoch[43] Evaluation metric 'epoch_loss'=86.063796
# Epoch[44] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 29.70it/s, epoch=45/50, avg_epoch_loss=83.3]
# Epoch[44] Elapsed time 1.079 seconds
# Epoch[44] Evaluation metric 'epoch_loss'=83.301870
# Epoch[45] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 29.77it/s, epoch=46/50, avg_epoch_loss=84.4]
# Epoch[45] Elapsed time 1.076 seconds
# Epoch[45] Evaluation metric 'epoch_loss'=84.370345
# Epoch[46] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 30.12it/s, epoch=47/50, avg_epoch_loss=70.7]
# Epoch[46] Elapsed time 1.064 seconds
# Epoch[46] Evaluation metric 'epoch_loss'=70.736477
# Epoch[47] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 30.43it/s, epoch=48/50, avg_epoch_loss=84.6]
# Epoch[47] Elapsed time 1.053 seconds
# Epoch[47] Evaluation metric 'epoch_loss'=84.628433
# Epoch[48] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 30.49it/s, epoch=49/50, avg_epoch_loss=81.5]
# Epoch[48] Elapsed time 1.051 seconds
# Epoch[48] Evaluation metric 'epoch_loss'=81.540587
# Epoch[49] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 30.49it/s, epoch=50/50, avg_epoch_loss=82.9]
# Epoch[49] Elapsed time 1.051 seconds
# Epoch[49] Evaluation metric 'epoch_loss'=82.883007
# Computing averaged parameters.
# Loading averaged parameters.
# End model training
#   0%|          | 0/370 [00:00<?, ?it/s]Forecast is not sample based. Ignoring parameter `num_samples` from predict method.
# 100%|██████████| 370/370 [00:00<00:00, 1916.03it/s]
# 100%|██████████| 370/370 [00:00<00:00, 4554.37it/s]
# Running evaluation: 100%|██████████| 370/370 [00:00<00:00, 2776.67it/s]
# Serializing RepresentableBlockPredictor instances does not save the prediction network structure in a backwards-compatible manner. Be careful not to use this method in production.
# Fitting model: SFF ...
# Start model training
# Epoch[0] Learning rate is 0.001
#   0%|          | 0/32 [00:00<?, ?it/s]Number of parameters in SimpleFeedForwardTrainingNetwork: 40483
# learning rate from ``lr_scheduler`` has been overwritten by ``learning_rate`` in optimizer.
# 100%|██████████| 32/32 [00:00<00:00, 115.70it/s, epoch=1/50, avg_epoch_loss=5.62]
# Epoch[0] Elapsed time 0.278 seconds
# Epoch[0] Evaluation metric 'epoch_loss'=5.616198
# Epoch[1] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 135.42it/s, epoch=2/50, avg_epoch_loss=4.78]
# Epoch[1] Elapsed time 0.237 seconds
# Epoch[1] Evaluation metric 'epoch_loss'=4.775357
# Epoch[2] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 135.05it/s, epoch=3/50, avg_epoch_loss=4.72]
# Epoch[2] Elapsed time 0.238 seconds
# Epoch[2] Evaluation metric 'epoch_loss'=4.715348
# Epoch[3] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 133.61it/s, epoch=4/50, avg_epoch_loss=4.63]
# Epoch[3] Elapsed time 0.241 seconds
# Epoch[3] Evaluation metric 'epoch_loss'=4.628327
# Epoch[4] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 134.61it/s, epoch=5/50, avg_epoch_loss=4.54]
# Epoch[4] Elapsed time 0.239 seconds
# Epoch[4] Evaluation metric 'epoch_loss'=4.539049
# Epoch[5] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 132.05it/s, epoch=6/50, avg_epoch_loss=4.59]
# Epoch[5] Elapsed time 0.244 seconds
# Epoch[5] Evaluation metric 'epoch_loss'=4.586138
# Epoch[6] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 146.49it/s, epoch=7/50, avg_epoch_loss=4.56]
# Epoch[6] Elapsed time 0.220 seconds
# Epoch[6] Evaluation metric 'epoch_loss'=4.558386
# Epoch[7] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 153.49it/s, epoch=8/50, avg_epoch_loss=4.53]
# Epoch[7] Elapsed time 0.210 seconds
# Epoch[7] Evaluation metric 'epoch_loss'=4.527613
# Epoch[8] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 142.28it/s, epoch=9/50, avg_epoch_loss=4.55]
# Epoch[8] Elapsed time 0.226 seconds
# Epoch[8] Evaluation metric 'epoch_loss'=4.553130
# Epoch[9] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 149.74it/s, epoch=10/50, avg_epoch_loss=4.39]
# Epoch[9] Elapsed time 0.215 seconds
# Epoch[9] Evaluation metric 'epoch_loss'=4.391541
# Epoch[10] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 155.77it/s, epoch=11/50, avg_epoch_loss=4.51]
# Epoch[10] Elapsed time 0.206 seconds
# Epoch[10] Evaluation metric 'epoch_loss'=4.507668
# Epoch[11] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 143.97it/s, epoch=12/50, avg_epoch_loss=4.51]
# Epoch[11] Elapsed time 0.224 seconds
# Epoch[11] Evaluation metric 'epoch_loss'=4.512041
# Epoch[12] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 139.35it/s, epoch=13/50, avg_epoch_loss=4.52]
# Epoch[12] Elapsed time 0.231 seconds
# Epoch[12] Evaluation metric 'epoch_loss'=4.522992
# Epoch[13] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 146.51it/s, epoch=14/50, avg_epoch_loss=4.56]
# Epoch[13] Elapsed time 0.219 seconds
# Epoch[13] Evaluation metric 'epoch_loss'=4.563510
# Epoch[14] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 152.06it/s, epoch=15/50, avg_epoch_loss=4.49]
# Epoch[14] Elapsed time 0.212 seconds
# Epoch[14] Evaluation metric 'epoch_loss'=4.485421
# Epoch[15] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 143.28it/s, epoch=16/50, avg_epoch_loss=4.52]
# Epoch[15] Elapsed time 0.225 seconds
# Epoch[15] Evaluation metric 'epoch_loss'=4.515876
# Epoch[16] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 145.79it/s, epoch=17/50, avg_epoch_loss=4.47]
# Epoch[16] Elapsed time 0.221 seconds
# Epoch[16] Evaluation metric 'epoch_loss'=4.470702
# Epoch[17] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 153.75it/s, epoch=18/50, avg_epoch_loss=4.55]
# Epoch[17] Elapsed time 0.209 seconds
# Epoch[17] Evaluation metric 'epoch_loss'=4.550133
# Epoch[18] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 151.55it/s, epoch=19/50, avg_epoch_loss=4.37]
# Epoch[18] Elapsed time 0.212 seconds
# Epoch[18] Evaluation metric 'epoch_loss'=4.372190
# Epoch[19] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 149.88it/s, epoch=20/50, avg_epoch_loss=4.42]
# Epoch[19] Elapsed time 0.215 seconds
# Epoch[19] Evaluation metric 'epoch_loss'=4.416248
# Epoch[20] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 149.63it/s, epoch=21/50, avg_epoch_loss=4.45]
# Epoch[20] Elapsed time 0.215 seconds
# Epoch[20] Evaluation metric 'epoch_loss'=4.446449
# Epoch[21] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 129.75it/s, epoch=22/50, avg_epoch_loss=4.48]
# Epoch[21] Elapsed time 0.248 seconds
# Epoch[21] Evaluation metric 'epoch_loss'=4.478322
# Epoch[22] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 145.98it/s, epoch=23/50, avg_epoch_loss=4.36]
# Epoch[22] Elapsed time 0.220 seconds
# Epoch[22] Evaluation metric 'epoch_loss'=4.356745
# Epoch[23] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 150.03it/s, epoch=24/50, avg_epoch_loss=4.45]
# Epoch[23] Elapsed time 0.214 seconds
# Epoch[23] Evaluation metric 'epoch_loss'=4.452986
# Epoch[24] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 143.59it/s, epoch=25/50, avg_epoch_loss=4.44]
# Epoch[24] Elapsed time 0.224 seconds
# Epoch[24] Evaluation metric 'epoch_loss'=4.440291
# Epoch[25] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 149.27it/s, epoch=26/50, avg_epoch_loss=4.45]
# Epoch[25] Elapsed time 0.215 seconds
# Epoch[25] Evaluation metric 'epoch_loss'=4.453004
# Epoch[26] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 141.78it/s, epoch=27/50, avg_epoch_loss=4.42]
# Epoch[26] Elapsed time 0.227 seconds
# Epoch[26] Evaluation metric 'epoch_loss'=4.422128
# Epoch[27] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 145.80it/s, epoch=28/50, avg_epoch_loss=4.4]
# Epoch[27] Elapsed time 0.221 seconds
# Epoch[27] Evaluation metric 'epoch_loss'=4.400470
# Epoch[28] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 141.02it/s, epoch=29/50, avg_epoch_loss=4.4]
# Epoch[28] Elapsed time 0.228 seconds
# Epoch[28] Evaluation metric 'epoch_loss'=4.397810
# Epoch[29] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 142.38it/s, epoch=30/50, avg_epoch_loss=4.39]
# Epoch[29] Elapsed time 0.226 seconds
# Epoch[29] Evaluation metric 'epoch_loss'=4.390308
# Epoch[30] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 138.34it/s, epoch=31/50, avg_epoch_loss=4.5]
# Epoch[30] Elapsed time 0.232 seconds
# Epoch[30] Evaluation metric 'epoch_loss'=4.500897
# Epoch[31] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 152.61it/s, epoch=32/50, avg_epoch_loss=4.34]
# Epoch[31] Elapsed time 0.211 seconds
# Epoch[31] Evaluation metric 'epoch_loss'=4.341249
# Epoch[32] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 139.48it/s, epoch=33/50, avg_epoch_loss=4.38]
# Epoch[32] Elapsed time 0.231 seconds
# Epoch[32] Evaluation metric 'epoch_loss'=4.379276
# Epoch[33] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 149.78it/s, epoch=34/50, avg_epoch_loss=4.43]
# Epoch[33] Elapsed time 0.215 seconds
# Epoch[33] Evaluation metric 'epoch_loss'=4.428063
# Epoch[34] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 152.97it/s, epoch=35/50, avg_epoch_loss=4.4]
# Epoch[34] Elapsed time 0.210 seconds
# Epoch[34] Evaluation metric 'epoch_loss'=4.401884
# Epoch[35] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 152.62it/s, epoch=36/50, avg_epoch_loss=4.44]
# Epoch[35] Elapsed time 0.211 seconds
# Epoch[35] Evaluation metric 'epoch_loss'=4.438688
# Epoch[36] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 145.71it/s, epoch=37/50, avg_epoch_loss=4.5]
# Epoch[36] Elapsed time 0.221 seconds
# Epoch[36] Evaluation metric 'epoch_loss'=4.495881
# Epoch[37] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 149.12it/s, epoch=38/50, avg_epoch_loss=4.32]
# Epoch[37] Elapsed time 0.216 seconds
# Epoch[37] Evaluation metric 'epoch_loss'=4.317121
# Epoch[38] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 145.88it/s, epoch=39/50, avg_epoch_loss=4.39]
# Epoch[38] Elapsed time 0.220 seconds
# Epoch[38] Evaluation metric 'epoch_loss'=4.390922
# Epoch[39] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 152.15it/s, epoch=40/50, avg_epoch_loss=4.51]
# Epoch[39] Elapsed time 0.212 seconds
# Epoch[39] Evaluation metric 'epoch_loss'=4.508502
# Epoch[40] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 103.16it/s, epoch=41/50, avg_epoch_loss=4.39]
# Epoch[40] Elapsed time 0.312 seconds
# Epoch[40] Evaluation metric 'epoch_loss'=4.392361
# Epoch[41] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 152.57it/s, epoch=42/50, avg_epoch_loss=4.34]
# Epoch[41] Elapsed time 0.211 seconds
# Epoch[41] Evaluation metric 'epoch_loss'=4.335363
# Epoch[42] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 140.15it/s, epoch=43/50, avg_epoch_loss=4.34]
# Epoch[42] Elapsed time 0.230 seconds
# Epoch[42] Evaluation metric 'epoch_loss'=4.339947
# Epoch[43] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 153.01it/s, epoch=44/50, avg_epoch_loss=4.38]
# Epoch[43] Elapsed time 0.210 seconds
# Epoch[43] Evaluation metric 'epoch_loss'=4.375992
# Epoch[44] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 140.19it/s, epoch=45/50, avg_epoch_loss=4.39]
# Epoch[44] Elapsed time 0.230 seconds
# Epoch[44] Evaluation metric 'epoch_loss'=4.394341
# Epoch[45] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 136.93it/s, epoch=46/50, avg_epoch_loss=4.4]
# Epoch[45] Elapsed time 0.235 seconds
# Epoch[45] Evaluation metric 'epoch_loss'=4.400702
# Epoch[46] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 152.25it/s, epoch=47/50, avg_epoch_loss=4.39]
# Epoch[46] Elapsed time 0.211 seconds
# Epoch[46] Evaluation metric 'epoch_loss'=4.387090
# Epoch[47] Learning rate is 0.001
# 100%|██████████| 32/32 [00:00<00:00, 153.50it/s, epoch=48/50, avg_epoch_loss=4.46]
# Epoch[47] Elapsed time 0.210 seconds
# Epoch[47] Evaluation metric 'epoch_loss'=4.464404
# Loading parameters from best epoch (37)
# Epoch[48] Learning rate is 0.0005
# 100%|██████████| 32/32 [00:00<00:00, 146.34it/s, epoch=49/50, avg_epoch_loss=4.4]
# Epoch[48] Elapsed time 0.220 seconds
# Epoch[48] Evaluation metric 'epoch_loss'=4.402950
# Epoch[49] Learning rate is 0.0005
# 100%|██████████| 32/32 [00:00<00:00, 153.07it/s, epoch=50/50, avg_epoch_loss=4.39]
# Epoch[49] Elapsed time 0.210 seconds
# Epoch[49] Evaluation metric 'epoch_loss'=4.394156
# Computing averaged parameters.
# Loading averaged parameters.
# End model training
# 100%|██████████| 370/370 [00:00<00:00, 3558.77it/s]
# 100%|██████████| 370/370 [00:00<00:00, 4226.48it/s]
# Running evaluation: 100%|██████████| 370/370 [00:00<00:00, 2867.04it/s]
# Serializing RepresentableBlockPredictor instances does not save the prediction network structure in a backwards-compatible manner. Be careful not to use this method in production.
# Fitting model: DeepAR ...
# Start model training
# Epoch[0] Learning rate is 0.001
#   0%|          | 0/32 [00:00<?, ?it/s]
# learning rate from ``lr_scheduler`` has been overwritten by ``learning_rate`` in optimizer.
# Number of parameters in DeepARTrainingNetwork: 27644
# 100%|██████████| 32/32 [00:02<00:00, 14.32it/s, epoch=1/50, avg_epoch_loss=6.3]
# Epoch[0] Elapsed time 2.237 seconds
# Epoch[0] Evaluation metric 'epoch_loss'=6.303856
# Epoch[1] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.78it/s, epoch=2/50, avg_epoch_loss=5]
# Epoch[1] Elapsed time 2.030 seconds
# Epoch[1] Evaluation metric 'epoch_loss'=5.001717
# Epoch[2] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.57it/s, epoch=3/50, avg_epoch_loss=4.58]
# Epoch[2] Elapsed time 2.057 seconds
# Epoch[2] Evaluation metric 'epoch_loss'=4.580605
# Epoch[3] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.58it/s, epoch=4/50, avg_epoch_loss=4.44]
# Epoch[3] Elapsed time 2.055 seconds
# Epoch[3] Evaluation metric 'epoch_loss'=4.435880
# Epoch[4] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.56it/s, epoch=5/50, avg_epoch_loss=4.16]
# Epoch[4] Elapsed time 2.057 seconds
# Epoch[4] Evaluation metric 'epoch_loss'=4.156487
# Epoch[5] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.74it/s, epoch=6/50, avg_epoch_loss=4.02]
# Epoch[5] Elapsed time 2.034 seconds
# Epoch[5] Evaluation metric 'epoch_loss'=4.015863
# Epoch[6] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.71it/s, epoch=7/50, avg_epoch_loss=4.08]
# Epoch[6] Elapsed time 2.038 seconds
# Epoch[6] Evaluation metric 'epoch_loss'=4.078998
# Epoch[7] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.77it/s, epoch=8/50, avg_epoch_loss=4.04]
# Epoch[7] Elapsed time 2.031 seconds
# Epoch[7] Evaluation metric 'epoch_loss'=4.036940
# Epoch[8] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.48it/s, epoch=9/50, avg_epoch_loss=4.01]
# Epoch[8] Elapsed time 2.068 seconds
# Epoch[8] Evaluation metric 'epoch_loss'=4.013585
# Epoch[9] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.84it/s, epoch=10/50, avg_epoch_loss=3.94]
# Epoch[9] Elapsed time 2.021 seconds
# Epoch[9] Evaluation metric 'epoch_loss'=3.943522
# Epoch[10] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.76it/s, epoch=11/50, avg_epoch_loss=3.92]
# Epoch[10] Elapsed time 2.032 seconds
# Epoch[10] Evaluation metric 'epoch_loss'=3.918983
# Epoch[11] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.61it/s, epoch=12/50, avg_epoch_loss=3.86]
# Epoch[11] Elapsed time 2.051 seconds
# Epoch[11] Evaluation metric 'epoch_loss'=3.859518
# Epoch[12] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.62it/s, epoch=13/50, avg_epoch_loss=3.8]
# Epoch[12] Elapsed time 2.050 seconds
# Epoch[12] Evaluation metric 'epoch_loss'=3.801383
# Epoch[13] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.63it/s, epoch=14/50, avg_epoch_loss=3.78]
# Epoch[13] Elapsed time 2.049 seconds
# Epoch[13] Evaluation metric 'epoch_loss'=3.781997
# Epoch[14] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.38it/s, epoch=15/50, avg_epoch_loss=3.87]
# Epoch[14] Elapsed time 2.082 seconds
# Epoch[14] Evaluation metric 'epoch_loss'=3.866195
# Epoch[15] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.55it/s, epoch=16/50, avg_epoch_loss=3.81]
# Epoch[15] Elapsed time 2.059 seconds
# Epoch[15] Evaluation metric 'epoch_loss'=3.811762
# Epoch[16] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.59it/s, epoch=17/50, avg_epoch_loss=3.93]
# Epoch[16] Elapsed time 2.054 seconds
# Epoch[16] Evaluation metric 'epoch_loss'=3.926313
# Epoch[17] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.58it/s, epoch=18/50, avg_epoch_loss=3.84]
# Epoch[17] Elapsed time 2.055 seconds
# Epoch[17] Evaluation metric 'epoch_loss'=3.841341
# Epoch[18] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.58it/s, epoch=19/50, avg_epoch_loss=3.83]
# Epoch[18] Elapsed time 2.056 seconds
# Epoch[18] Evaluation metric 'epoch_loss'=3.832814
# Epoch[19] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.60it/s, epoch=20/50, avg_epoch_loss=3.78]
# Epoch[19] Elapsed time 2.053 seconds
# Epoch[19] Evaluation metric 'epoch_loss'=3.780984
# Epoch[20] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.60it/s, epoch=21/50, avg_epoch_loss=3.74]
# Epoch[20] Elapsed time 2.053 seconds
# Epoch[20] Evaluation metric 'epoch_loss'=3.740049
# Epoch[21] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.59it/s, epoch=22/50, avg_epoch_loss=3.79]
# Epoch[21] Elapsed time 2.053 seconds
# Epoch[21] Evaluation metric 'epoch_loss'=3.785448
# Epoch[22] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.46it/s, epoch=23/50, avg_epoch_loss=3.82]
# Epoch[22] Elapsed time 2.071 seconds
# Epoch[22] Evaluation metric 'epoch_loss'=3.819526
# Epoch[23] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.41it/s, epoch=24/50, avg_epoch_loss=3.8]
# Epoch[23] Elapsed time 2.077 seconds
# Epoch[23] Evaluation metric 'epoch_loss'=3.797852
# Epoch[24] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.45it/s, epoch=25/50, avg_epoch_loss=3.77]
# Epoch[24] Elapsed time 2.073 seconds
# Epoch[24] Evaluation metric 'epoch_loss'=3.769848
# Epoch[25] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 16.57it/s, epoch=26/50, avg_epoch_loss=3.8]
# Epoch[25] Elapsed time 1.932 seconds
# Epoch[25] Evaluation metric 'epoch_loss'=3.799641
# Epoch[26] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 16.34it/s, epoch=27/50, avg_epoch_loss=3.76]
# Epoch[26] Elapsed time 1.960 seconds
# Epoch[26] Evaluation metric 'epoch_loss'=3.759458
# Epoch[27] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 16.55it/s, epoch=28/50, avg_epoch_loss=3.7]
# Epoch[27] Elapsed time 1.934 seconds
# Epoch[27] Evaluation metric 'epoch_loss'=3.698188
# Epoch[28] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.81it/s, epoch=29/50, avg_epoch_loss=3.79]
# Epoch[28] Elapsed time 2.025 seconds
# Epoch[28] Evaluation metric 'epoch_loss'=3.793918
# Epoch[29] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 16.48it/s, epoch=30/50, avg_epoch_loss=3.8]
# Epoch[29] Elapsed time 1.943 seconds
# Epoch[29] Evaluation metric 'epoch_loss'=3.801918
# Epoch[30] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.35it/s, epoch=31/50, avg_epoch_loss=3.73]
# Epoch[30] Elapsed time 2.086 seconds
# Epoch[30] Evaluation metric 'epoch_loss'=3.727221
# Epoch[31] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.53it/s, epoch=32/50, avg_epoch_loss=3.79]
# Epoch[31] Elapsed time 2.061 seconds
# Epoch[31] Evaluation metric 'epoch_loss'=3.789721
# Epoch[32] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.65it/s, epoch=33/50, avg_epoch_loss=3.75]
# Epoch[32] Elapsed time 2.046 seconds
# Epoch[32] Evaluation metric 'epoch_loss'=3.752036
# Epoch[33] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.63it/s, epoch=34/50, avg_epoch_loss=3.7]
# Epoch[33] Elapsed time 2.049 seconds
# Epoch[33] Evaluation metric 'epoch_loss'=3.704019
# Epoch[34] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.68it/s, epoch=35/50, avg_epoch_loss=3.74]
# Epoch[34] Elapsed time 2.043 seconds
# Epoch[34] Evaluation metric 'epoch_loss'=3.739717
# Epoch[35] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.53it/s, epoch=36/50, avg_epoch_loss=3.74]
# Epoch[35] Elapsed time 2.062 seconds
# Epoch[35] Evaluation metric 'epoch_loss'=3.737909
# Epoch[36] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.52it/s, epoch=37/50, avg_epoch_loss=3.74]
# Epoch[36] Elapsed time 2.063 seconds
# Epoch[36] Evaluation metric 'epoch_loss'=3.735208
# Epoch[37] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.52it/s, epoch=38/50, avg_epoch_loss=3.69]
# Epoch[37] Elapsed time 2.064 seconds
# Epoch[37] Evaluation metric 'epoch_loss'=3.687069
# Epoch[38] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 14.88it/s, epoch=39/50, avg_epoch_loss=3.79]
# Epoch[38] Elapsed time 2.152 seconds
# Epoch[38] Evaluation metric 'epoch_loss'=3.786228
# Epoch[39] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 16.23it/s, epoch=40/50, avg_epoch_loss=3.73]
# Epoch[39] Elapsed time 1.973 seconds
# Epoch[39] Evaluation metric 'epoch_loss'=3.729462
# Epoch[40] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 16.67it/s, epoch=41/50, avg_epoch_loss=3.71]
# Epoch[40] Elapsed time 1.922 seconds
# Epoch[40] Evaluation metric 'epoch_loss'=3.711446
# Epoch[41] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 16.65it/s, epoch=42/50, avg_epoch_loss=3.69]
# Epoch[41] Elapsed time 1.924 seconds
# Epoch[41] Evaluation metric 'epoch_loss'=3.694982
# Epoch[42] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 16.57it/s, epoch=43/50, avg_epoch_loss=3.75]
# Epoch[42] Elapsed time 1.932 seconds
# Epoch[42] Evaluation metric 'epoch_loss'=3.754245
# Epoch[43] Learning rate is 0.001
# 100%|██████████| 32/32 [00:01<00:00, 16.01it/s, epoch=44/50, avg_epoch_loss=3.69]
# Epoch[43] Elapsed time 2.001 seconds
# Epoch[43] Evaluation metric 'epoch_loss'=3.688945
# Epoch[44] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.71it/s, epoch=45/50, avg_epoch_loss=3.66]
# Epoch[44] Elapsed time 2.038 seconds
# Epoch[44] Evaluation metric 'epoch_loss'=3.657966
# Epoch[45] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.67it/s, epoch=46/50, avg_epoch_loss=3.73]
# Epoch[45] Elapsed time 2.044 seconds
# Epoch[45] Evaluation metric 'epoch_loss'=3.727721
# Epoch[46] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.71it/s, epoch=47/50, avg_epoch_loss=3.65]
# Epoch[46] Elapsed time 2.038 seconds
# Epoch[46] Evaluation metric 'epoch_loss'=3.647902
# Epoch[47] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.77it/s, epoch=48/50, avg_epoch_loss=3.64]
# Epoch[47] Elapsed time 2.031 seconds
# Epoch[47] Evaluation metric 'epoch_loss'=3.638218
# Epoch[48] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.73it/s, epoch=49/50, avg_epoch_loss=3.77]
# Epoch[48] Elapsed time 2.035 seconds
# Epoch[48] Evaluation metric 'epoch_loss'=3.769821
# Epoch[49] Learning rate is 0.001
# 100%|██████████| 32/32 [00:02<00:00, 15.70it/s, epoch=50/50, avg_epoch_loss=3.7]
# Epoch[49] Elapsed time 2.039 seconds
# Epoch[49] Evaluation metric 'epoch_loss'=3.700804
# Computing averaged parameters.
# Loading averaged parameters.
# End model training
# 100%|██████████| 370/370 [00:02<00:00, 126.69it/s]
# 100%|██████████| 370/370 [00:00<00:00, 4592.44it/s]
# Running evaluation: 100%|██████████| 370/370 [00:00<00:00, 2541.69it/s]
# Serializing RepresentableBlockPredictor instances does not save the prediction network structure in a backwards-compatible manner. Be careful not to use this method in production.
# AutoGluon training complete, total runtime = 170.44s ...

# %%
print(predictor.leaderboard())
# Out:
# /home/ubuntu/anaconda3/envs/ag_forecast/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Generating leaderboard for all models trained...
#     model     score  fit_order
# 0  DeepAR -0.075928          3
# 1     SFF -0.080284          2
# 2   MQCNN -0.087421          1

# %%
print(predictor.evaluate(test_data))
# Out:
# /home/ubuntu/anaconda3/envs/ag_forecast/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Does not specify model, will by default use the model with the best validation score for evaluation
# 100%|██████████| 2590/2590 [00:23<00:00, 109.58it/s]
# 100%|██████████| 2590/2590 [00:01<00:00, 1387.55it/s]
# Running evaluation: 100%|██████████| 2590/2590 [00:00<00:00, 14813.87it/s]
# 0.09072135773721754
